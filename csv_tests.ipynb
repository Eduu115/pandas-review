# %%
import pandas as pd

# %%
richest = pd.read_csv('TopRichestInWorld.csv', usecols=['Name']).squeeze() # el squeeze lo que hace es convertirlo en Series
richest
# Out:
# 0                     Elon Musk
# 1                    Jeff Bezos
# 2      Bernard Arnault & family
# 3                    Bill Gates
# 4                Warren Buffett
#                  ...
# 96             Vladimir Potanin
# 97         Harold Hamm & family
# 98                 Sun Piaoyang
# 99           Luo Liguo & family
# 100                   Peter Woo
# Name: Name, Length: 101, dtype: str

# %%
type(richest)
# Out:
# pandas.Series

# %%
richest.to_csv('test_richest.csv', index=False)

# %%
people = pd.read_csv('test_richest.csv')
people
# Out:
#                          Name
# 0                   Elon Musk
# 1                  Jeff Bezos
# 2    Bernard Arnault & family
# 3                  Bill Gates
# 4              Warren Buffett
# ..                        ...
# 96           Vladimir Potanin
# 97       Harold Hamm & family
# 98               Sun Piaoyang
# 99         Luo Liguo & family
# 100                 Peter Woo
#
# [101 rows x 1 columns]

# %%
pd.read_csv('test_richest.csv').tail(10)
# Out:
#                         Name
# 91   Savitri Jindal & family
# 92               Wang Wenyin
# 93                 Li Xiting
# 94            Stefan Persson
# 95               Steve Cohen
# 96          Vladimir Potanin
# 97      Harold Hamm & family
# 98              Sun Piaoyang
# 99        Luo Liguo & family
# 100                Peter Woo

# %%
richest.sort_values(
                        axis=0,
                        ascending=True,
                        kind='quicksort',
                        na_position= 'last',
                        ignore_index=True
                    )
# Out:
# 0           Abigail Johnson
# 1          Alain Wertheimer
# 2              Alice Walton
# 3            Amancio Ortega
# 4            Andrew Forrest
#                ...
# 96           Warren Buffett
# 97         William Lei Ding
# 98     Yang Huiyan & family
# 99             Zhang Yiming
# 100          Zhong Shanshan
# Name: Name, Length: 101, dtype: str

# %% [markdown]
# ### Ahora vamos con otras columnas

# %%
richestv2 = pd.read_csv('TopRichestInWorld.csv', usecols=['Industry']).squeeze()
richestv2
# Out:
# 0                 Automotive
# 1                 Technology
# 2           Fashion & Retail
# 3                 Technology
# 4      Finance & Investments
#                ...
# 96           Metals & Mining
# 97                    Energy
# 98                Healthcare
# 99             Manufacturing
# 100              Real Estate
# Name: Industry, Length: 101, dtype: str

# %%
richestv2.value_counts()
# Out:
# Industry
# Fashion & Retail         18
# Technology               15
# Finance & Investments    13
# Metals & Mining           9
# Food & Beverage           8
# Automotive                7
# Diversified               6
# Manufacturing             5
# Healthcare                5
# Media & Entertainment     4
# Real Estate               3
# Telecom                   2
# Logistics                 2
# Energy                    2
# Gambling & Casinos        1
# Service                   1
# Name: count, dtype: int64

# %%
richestv2.value_counts(normalize=True,
                       ascending=True,
                       dropna=True)
# Out:
# Industry
# Gambling & Casinos       0.009901
# Service                  0.009901
# Telecom                  0.019802
# Logistics                0.019802
# Energy                   0.019802
# Real Estate              0.029703
# Media & Entertainment    0.039604
# Manufacturing            0.049505
# Healthcare               0.049505
# Diversified              0.059406
# Automotive               0.069307
# Food & Beverage          0.079208
# Metals & Mining          0.089109
# Finance & Investments    0.128713
# Technology               0.148515
# Fashion & Retail         0.178218
# Name: proportion, dtype: float64

# %%
richest = pd.read_csv('TopRichestInWorld.csv', usecols=['Age']).squeeze()
richest
# Out:
# 0      50
# 1      58
# 2      73
# 3      66
# 4      91
#        ..
# 96     61
# 97     76
# 98     63
# 99     66
# 100    75
# Name: Age, Length: 101, dtype: int64

# %%
richest.value_counts(bins=3)
# Out:
# (51.333, 72.667]    47
# (72.667, 94.0]      39
# (29.935, 51.333]    15
# Name: count, dtype: int64

# %% [markdown]
# ### POSICIONES

# %%
richest.head(10) #top x
# Out:
# 0    50
# 1    58
# 2    73
# 3    66
# 4    91
# 5    49
# 6    48
# 7    77
# 8    66
# 9    64
# Name: Age, dtype: int64

# %%
richest[[1,2,15]] # especificas
# Out:
# 1     58
# 2     73
# 15    73
# Name: Age, dtype: int64

# %%
richest[5:10] # de 5 a 10
# Out:
# 5    49
# 6    48
# 7    77
# 8    66
# 9    64
# Name: Age, dtype: int64

# %%
richest[0:21:5] # de 0 a 21 skipeando 5
# Out:
# 0     50
# 5     49
# 10    59
# 15    73
# 20    86
# Name: Age, dtype: int64

# %%
richest[:10] # todo hasta 10
# Out:
# 0    50
# 1    58
# 2    73
# 3    66
# 4    91
# 5    49
# 6    48
# 7    77
# 8    66
# 9    64
# Name: Age, dtype: int64

# %%
# richest[-1] # asi no

# %%
richest[-1:] # asi si, con : al final, para acceder al -x posicion
# Out:
# 100    75
# Name: Age, dtype: int64

# %% [markdown]
# #### LO VEMOS CON LA TABLA CSV
