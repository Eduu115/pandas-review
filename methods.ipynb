# %%
import pandas as pd

# %%
values = pd.Series(data=[1.5,2.5,0.5,None,4.0,1.0])

# %%
values.max()
# Out:
# np.float64(4.0)

# %%
values.isnull()
# Out:
# 0    False
# 1    False
# 2    False
# 3     True
# 4    False
# 5    False
# dtype: bool

# %%
values.round()
# Out:
# 0    1.5
# 1    2.5
# 2    0.5
# 3    NaN
# 4    4.0
# 5    1.0
# dtype: float64
